# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('FinalJobData.csv')

# %%
data.head()
# Out:
#    OpenSource_Yes  Gender_Female  Gender_Female;Male  \
# 0               0              0                   0
# 1               1              0                   0
# 2               0              0                   0
# 3               0              0                   0
# 4               0              0                   0
#
#    Gender_Female;Male;Non-binary, genderqueer, or gender non-conforming  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Employment_Employed full-time  Employment_Employed part-time  \
# 0                              0                              1
# 1                              1                              0
# 2                              1                              0
# 3                              1                              0
# 4                              1                              0
#
#    Employment_Independent contractor, freelancer, or self-employed  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Employment_Not employed, but looking for work  \
# 0                                              0
# 1                                              0
# 2                                              0
# 3                                              0
# 4                                              0
#
#    FormalEducation_Associate degree  \
# 0                                 0
# 1                                 0
# 2                                 0
# 3                                 0
# 4                                 0
#
#    FormalEducation_Bachelorâ€™s degree (BA, BS, B.Eng., etc.)  ...  \
# 0                                                  1           ...
# 1                                                  1           ...
# 2                                                  1           ...
# 3                                                  0           ...
# 4                                                  1           ...
#
#    YearsCoding_15-17 years  YearsCoding_18-20 years  YearsCoding_21-23 years  \
# 0                        0                        0                        0
# 1                        0                        0                        0
# 2                        0                        1                        0
# 3                        0                        0                        0
# 4                        0                        0                        0
#
#    YearsCoding_24-26 years  YearsCoding_27-29 years  YearsCoding_3-5 years  \
# 0                        0                        0                      1
# 1                        0                        0                      0
# 2                        0                        0                      0
# 3                        0                        0                      0
# 4                        0                        0                      0
#
#    YearsCoding_30 or more years  YearsCoding_6-8 years  \
# 0                             0                      0
# 1                             1                      0
# 2                             0                      0
# 3                             0                      1
# 4                             0                      1
#
#    YearsCoding_9-11 years                       Job
# 0                       0      Full-stack developer
# 1                       0    Database administrator
# 2                       0      Full-stack developer
# 3                       0  Data or business analyst
# 4                       0        Back-end developer
#
# [5 rows x 32 columns]

# %%
x=data.drop('Job',axis='columns') 
y=data['Job']
x.head()
y.head()
# Out:
# 0        Full-stack developer
# 1      Database administrator
# 2        Full-stack developer
# 3    Data or business analyst
# 4          Back-end developer
# Name: Job, dtype: object

# %%
from sklearn import tree
model = tree.DecisionTreeClassifier(criterion='entropy')
from sklearn.model_selection import train_test_split
x_train,x_test,y_train, y_test=train_test_split(x,y,test_size=0.2)
model.fit(x_train,y_train)
model.score(x_test,y_test)
prediction = model.predict(x_test)
print(type(prediction))
# Out:
# <class 'numpy.ndarray'>

# %%
prediction = pd.DataFrame(prediction, columns=['predictions']).to_csv('prediction.csv')

# %%
import pickle

# %%
filename = 'finalized_model.sav'
pickle.dump(model, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))
result = loaded_model.score(x_test, y_test)
print(result)
# Out:
# 0.5954941590951233
